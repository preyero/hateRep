# %% [markdown]
# # Entity recognition with KG (GSSO)
#
# This notebook samples messages to get a diverse vocabulary, taking from repeated most important features the ones with the highest probability > export data_sampling/sampling.json
#
# We obtain 350 unique posts from 4 hate speech databases.

# %%
import os, json
import pandas as pd
import numpy as np
from typing import List

out_path = os.path.join('data_sampling')
os.makedirs(out_path, exist_ok=True)

# FP sample with contradictory model predictions and aggregated annotations: 1789 comments
d = pd.read_csv(os.path.join('data_selection', 'mhs_fp.csv'))
text_col, id_col = 'predict_text', 'comment_id'
print(d.shape)
d.head(2)
# Out:
# (1789, 63)
#    comment_id  target_age  target_age_children  target_age_middle_aged  \
# 0          29           0                    0                       0
# 1          86           0                    0                       0
#
#    target_age_other  target_age_seniors  target_age_teenagers  \
# 0                 0                   0                     0
# 1                 0                   0                     0
#
#    target_age_young_adults  target_disability  target_disability_cognitive  \
# 0                        0                  0                            0
# 1                        0                  0                            0
#
#    ...  target_religion_muslim  target_religion_other  target_sexuality  \
# 0  ...                       0                      0                 0
# 1  ...                       0                      0                 0
#
#    target_sexuality_bisexual  target_sexuality_gay  \
# 0                          0                     0
# 1                          0                     0
#
#    target_sexuality_homosexual  target_sexuality_lesbian  \
# 0                            0                         0
# 1                            0                         0
#
#    target_sexuality_other  target_sexuality_straight  \
# 0                       0                          0
# 1                       0                          0
#
#                                         predict_text
# 0  i'm absolutely for equal rights for all people...
# 1  jesus christ why do niggers always have to sho...
#
# [2 rows x 63 columns]

# %% [markdown]
# ## Training data

# %%
# Step by step on training data
print(d.loc[:5,'target_gso_Def'])
d['categories'] = d['target_gso_Def'].astype('category').cat.codes
y = d['categories']
print(y[:6])
# Because, e.g., there are 695 examples with female, 432 with male
# Out:
# 0    Identification as male/masculine, female/femin...
# 1    A person whose identity is male, based on soci...
# 2    A person whose identity is male, based on soci...
# 3    A person whose identity is female, based on so...
# 4    A person whose identity is male, based on soci...
# 5    Typically, someone with a female gender identi...
# Name: target_gso_Def, dtype: object
# 0     96
# 1     42
# 2     42
# 3     41
# 4     42
# 5    127
# Name: categories, dtype: int16

# %%
# Number of all different entities found, and the ones with more than 2 occurrences
y_counts = y.value_counts().to_dict()
print(len(y_counts))
print('entities more than twice:', len([k for k,v in y_counts.items() if v > 2]))
print('twice or less:', len([k for k,v in y_counts.items() if v <= 2]))
print(y_counts)
# Out:
# 130
# entities more than twice: 36
# twice or less: 94
# {41: 695, 42: 432, 129: 118, 111: 70, 62: 34, 124: 34, 110: 31, 94: 26, 25: 26, 83: 25, 93: 22, 96: 22, 24: 15, 26: 12, 123: 11, 101: 10, 4: 10, 21: 10, 44: 8, 80: 7, 56: 5, 75: 5, 0: 4, 95: 4, 45: 4, 71: 4, 107: 4, 76: 4, 10: 3, 114: 3, 103: 3, 39: 3, 31: 3, 52: 3, 28: 3, 53: 3, 63: 2, 65: 2, 9: 2, 109: 2, 48: 2, 108: 2, 15: 2, 36: 2, 91: 2, 74: 2, 72: 2, 77: 2, 33: 2, 29: 2, 1: 2, 70: 2, 5: 2, 117: 2, 87: 2, 102: 1, 50: 1, 6: 1, 82: 1, 92: 1, 19: 1, 40: 1, 126: 1, 54: 1, 8: 1, 113: 1, 81: 1, 13: 1, 106: 1, 22: 1, 34: 1, 7: 1, 11: 1, 47: 1, 122: 1, 97: 1, 60: 1, 84: 1, 59: 1, 35: 1, 68: 1, 23: 1, 17: 1, 99: 1, 104: 1, 116: 1, 112: 1, 120: 1, 121: 1, 86: 1, 98: 1, 85: 1, 58: 1, 20: 1, 46: 1, 27: 1, 90: 1, 128: 1, 38: 1, 37: 1, 119: 1, 64: 1, 105: 1, 32: 1, 69: 1, 67: 1, 66: 1, 127: 1, 2: 1, 16: 1, 88: 1, 14: 1, 49: 1, 18: 1, 55: 1, 73: 1, 118: 1, 115: 1, 57: 1, 125: 1, 43: 1, 61: 1, 51: 1, 12: 1, 89: 1, 30: 1, 3: 1, 78: 1, 79: 1, 100: 1}

# %%
# which categories (highest important entities) are the most frequqent in the error sample?
y_entities = {}
for pos, counts in y_counts.items():
    d_pos = d[(y == pos).values.tolist()].reset_index()
    y_entities[f'{pos}: {counts}'] = d_pos.loc[0,'target_gso_Label'].split(';')[0]
print(y_entities)
# Out:
# {'41: 695': 'woman', '42: 432': 'man', '129: 118': 'hers', '111: 70': 'pussy', '62: 34': '.gay', '124: 34': 'sex', '110: 31': 'heterosexual', '94: 26': 'male gender identity', '25: 26': 'bitch', '83: 25': 'sucking', '93: 22': 'female gender identity', '96: 22': 'gender', '24: 15': 'marital partner', '26: 12': 'faggot', '123: 11': 'sexuality', '101: 10': 'semen', '4: 10': 'parent', '21: 10': 'mixed-orientation marriage', '44: 8': 'homophobia', '80: 7': 'body', '56: 5': 'face', '75: 5': 'LGBT', '0: 4': 'das', '95: 4': 'bisexual', '45: 4': 'dyadic relationship', '71: 4': 'homosexualism', '107: 4': 'gay', '76: 4': 'LGBTQ', '10: 3': 'marriage', '114: 3': 'interpersonal attraction', '103: 3': 'mouth', '39: 3': 'sibling', '31: 3': 'friend', '52: 3': 'partner', '28: 3': 'muxe', '53: 3': 'HIV positive', '63: 2': 'instant messaging', '65: 2': 'word', '9: 2': 'clothing', '109: 2': 'anal intercourse', '48: 2': 'community', '108: 2': 'sexual intercourse', '15: 2': 'family', '36: 2': 'single person', '91: 2': 'flatulence', '74: 2': 'rapist', '72: 2': 'personal name', '77: 2': 'life', '33: 2': 'immigrant', '29: 2': 'artist', '1: 2': 't!un', '70: 2': 'hole', '5: 2': 'movement', '117: 2': 'pornography', '87: 2': 'death', '102: 1': 'anus', '50: 1': 'affair', '6: 1': 'cousin', '82: 1': 'sport', '92: 1': 'hate', '19: 1': 'list', '40: 1': 'advocate', '126: 1': 'murder', '54: 1': 'anger', '8: 1': 'Italy', '113: 1': 'intellectual disability', '81: 1': 'money', '13: 1': 'file', '106: 1': 'day', '22: 1': 'number', '34: 1': 'sodomite', '7: 1': 'brown', '11: 1': 'fag', '47: 1': 'sentence', '122: 1': 'duke', '97: 1': 'identity', '60: 1': 'age', '84: 1': 'beating', '59: 1': 'symbol', '35: 1': 'prisoner', '68: 1': 'closeted', '23: 1': 'grandparent', '17: 1': 'nail', '99: 1': 'masculism', '104: 1': 'Latina woman', '116: 1': 'yellow', '112: 1': 'top', '120: 1': 'plasticity', '121: 1': 'shaving', '86: 1': 'exposure', '98: 1': 'engaged', '85: 1': 'media', '58: 1': 'minority group', '20: 1': 'necktie', '46: 1': 'relationship', '27: 1': 'sissy', '90: 1': 'weapon', '128: 1': 'cunt', '38: 1': 'performing artist', '37: 1': 'user', '119: 1': 'equality', '64: 1': 'gun weapon', '105: 1': 'queer sexual orientation', '32: 1': 'abusive person', '69: 1': 'feminist', '67: 1': 'therapeutic procedure', '66: 1': 'abortion', '127: 1': 'lesbian', '2: 1': 'aggressive behavior', '16: 1': 'subculture', '88: 1': 'molly', '14: 1': 'exploring gender identity', '49: 1': 'sexual intercourse with internal ejaculation', '18: 1': 'finding', '55: 1': 'student', '73: 1': 'certified midwife', '118: 1': 'ability', '115: 1': 'foot', '57: 1': 'week', '125: 1': 'personal identity', '43: 1': 'surgeon', '61: 1': 'shipped relationship', '51: 1': 'gal', '12: 1': 'hair', '89: 1': 'fetus', '30: 1': 'agent', '3: 1': 'sword', '78: 1': 'object', '79: 1': 'eye', '100: 1': 'control'}

# %%
terms = []
for pos, counts in y_counts.items():
    d_pos = d[(y == pos).values.tolist()].reset_index()
    terms.append(d_pos.loc[0,'target_gso_Label'].split(';')[0])
print(terms)
# Out:
# ['woman', 'man', 'hers', 'pussy', '.gay', 'sex', 'heterosexual', 'male gender identity', 'bitch', 'sucking', 'female gender identity', 'gender', 'marital partner', 'faggot', 'sexuality', 'semen', 'parent', 'mixed-orientation marriage', 'homophobia', 'body', 'face', 'LGBT', 'das', 'bisexual', 'dyadic relationship', 'homosexualism', 'gay', 'LGBTQ', 'marriage', 'interpersonal attraction', 'mouth', 'sibling', 'friend', 'partner', 'muxe', 'HIV positive', 'instant messaging', 'word', 'clothing', 'anal intercourse', 'community', 'sexual intercourse', 'family', 'single person', 'flatulence', 'rapist', 'personal name', 'life', 'immigrant', 'artist', 't!un', 'hole', 'movement', 'pornography', 'death', 'anus', 'affair', 'cousin', 'sport', 'hate', 'list', 'advocate', 'murder', 'anger', 'Italy', 'intellectual disability', 'money', 'file', 'day', 'number', 'sodomite', 'brown', 'fag', 'sentence', 'duke', 'identity', 'age', 'beating', 'symbol', 'prisoner', 'closeted', 'grandparent', 'nail', 'masculism', 'Latina woman', 'yellow', 'top', 'plasticity', 'shaving', 'exposure', 'engaged', 'media', 'minority group', 'necktie', 'relationship', 'sissy', 'weapon', 'cunt', 'performing artist', 'user', 'equality', 'gun weapon', 'queer sexual orientation', 'abusive person', 'feminist', 'therapeutic procedure', 'abortion', 'lesbian', 'aggressive behavior', 'subculture', 'molly', 'exploring gender identity', 'sexual intercourse with internal ejaculation', 'finding', 'student', 'certified midwife', 'ability', 'foot', 'week', 'personal identity', 'surgeon', 'shipped relationship', 'gal', 'hair', 'fetus', 'agent', 'sword', 'object', 'eye', 'control']

# %%
# Use this diverse set of examples to generate a labeling task: with text, definition, and list of entities.
ids = []

# ... all unique occurrences
print('comment ids from all unique entities')
unique = [k for k,v in y_counts.items() if v<2]
print(len(unique))
print(unique)
ids+=d[(y.isin(unique))][id_col].to_list()
print(len(ids))

# ... highest probability in repeated entities
print('sampling entities with more than one occurrence')
print(d.shape)
d_sampling = d[~(y.isin(unique))]
print(d.shape[0]-len(ids))
print(d_sampling.shape)

print('number of classes corresp to repeated entities', 130-75)
y_classes = d_sampling['target_gso_Def'].astype('category').cat.codes
print(len(y_classes.value_counts()))

max_indices = d_sampling.groupby('categories')['target_gso_Pred'].idxmax()
print(len(max_indices))
ids+=d_sampling.loc[d_sampling.index.isin(max_indices), id_col].tolist()
print('resulting sampling ids', len(ids))
d_sampling.loc[d_sampling.index.isin(max_indices), [id_col, 'categories'] + [f'target_gso_{p}' for p in ['Label', 'Pred']]]
# Out:
# comment ids from all unique entities
# 75
# [102, 50, 6, 82, 92, 19, 40, 126, 54, 8, 113, 81, 13, 106, 22, 34, 7, 11, 47, 122, 97, 60, 84, 59, 35, 68, 23, 17, 99, 104, 116, 112, 120, 121, 86, 98, 85, 58, 20, 46, 27, 90, 128, 38, 37, 119, 64, 105, 32, 69, 67, 66, 127, 2, 16, 88, 14, 49, 18, 55, 73, 118, 115, 57, 125, 43, 61, 51, 12, 89, 30, 3, 78, 79, 100]
# 75
# sampling entities with more than one occurrence
# (1789, 64)
# 1714
# (1714, 64)
# number of classes corresp to repeated entities 55
# 55
# 55
# resulting sampling ids 130
#       comment_id  categories  \
# 22           888          70
# 154         6425          75
# 323        12497          41
# 355        13570          44
# 398        15066          42
# 480        18174         107
# 488        18453          71
# 494        18643           4
# 547        20522         103
# 564        20952          31
# 581        21431         101
# 600        22115          77
# 602        22145          24
# 628        22764          96
# 661        23572          62
# 674        23961         123
# 704        24928         109
# 705        24968         114
# 726        25616          80
# 757        26413         110
# 764        26720          56
# 779        27022         111
# 808        27941          74
# 826        28485         124
# 902        30388          76
# 934        31220          94
# 985        32077          28
# 1017       32925           9
# 1026       33276          10
# 1068       34548           1
# 1228       39114         117
# 1245       39594          53
# 1257       39900          65
# 1282       40398          72
# 1317       40906          25
# 1366       41735          48
# 1367       41737          36
# 1384       42143         129
# 1393       42315          26
# 1395       42363          93
# 1425       42814         108
# 1439       43080          45
# 1459       43420          52
# 1461       43491          63
# 1485       43987          33
# 1498       44278          15
# 1520       44627          21
# 1575       45777          39
# 1632       47124          91
# 1634       47143           0
# 1650       47428          95
# 1661       47572          83
# 1699       48228          29
# 1713       48450          87
# 1777       49708           5
#
#                                        target_gso_Label  target_gso_Pred
# 22                                      hole;bitch;fuck         0.557834
# 154   LGBT;.lgbt;r/lgbt;queer sexual orientation;per...         0.927318
# 323   woman;.gay;gay;heterosexual;asexual and homoro...         0.991958
# 355   homophobia;mixed-orientation marriage;quality;...         0.563604
# 398   man;.gay;gay;heterosexual;asexual and homoroma...         0.973066
# 480   gay;gay person;homosexuality;human homosexuali...         0.888273
# 488   homosexualism;sex;sexual intercourse;premarita...         0.567386
# 494   parent;semen;seminal emission;dwelling;licking...         0.604195
# 547   mouth;foot;hers;her;she;narrative;terrorism;to...         0.644858
# 564   friend;life;pussy;life cycle;artificial life;d...         0.662942
# 581   semen;lingerie;face;facial cum shot;sucking;he...         0.872051
# 600   life;life cycle;artificial life;family;hers;he...         0.603386
# 602   marital partner;fiancé;sexual intercourse with...         0.679840
# 628   gender;X-gender;grammatical gender;gender attr...         0.804340
# 661   .gay;gay;heterosexual;asexual and homoromantic...         0.975230
# 674   sexuality;sex;sexual intercourse;human sexuali...         0.605732
# 704          anal intercourse;pussy;killing;fuck;4-real         0.556444
# 705             interpersonal attraction;attractiveness         0.505080
# 726          body;pussy;sucking;human body;thinking;MTF         0.722476
# 757   heterosexual;marital partner;fiancé;asexual an...         0.830634
# 764                                     face;look;bitch         0.548030
# 779            pussy;bitch;myalgic encephalomyelitis;me         0.708661
# 808                                 rapist;sucking;ball         0.543753
# 826   sex;sexual intercourse;pussy;hers;violence;her...         0.835028
# 902                                  LGBTQ;hand;Germany         0.739299
# 934   male gender identity;.gay;gay;heterosexual;ase...         0.958303
# 985                                 muxe;pussy;she;fuck         0.653793
# 1017  clothing;marital partner;fiancé;face;hair;hers...         0.655633
# 1026  marriage;sex;partner;sexual intercourse;life;l...         0.525190
# 1068  t!un;sentence;HIV positive;hers;her;part of sp...         0.540873
# 1228                             pornography;pussy;fuck         0.634450
# 1245  HIV positive;HIV unknown;HIV negative;hers;her...         0.657720
# 1257  word;hers;her;saying;she;payment;partial andro...         0.555850
# 1282  personal name;figure;last name;hers;her;name;s...         0.590960
# 1317                                         bitch;fuck         0.544443
# 1366  community;research activity;hers;her;site;comm...         0.560691
# 1367  single person;marital partner;parent;single pa...         0.556473
# 1384                     hers;her;she;look;acting;her'n         0.683397
# 1393  faggot;finding;retrograde ejaculation;bitch;Mu...         0.697672
# 1395  female gender identity;body;human body;moment;...         0.818037
# 1425  sexual intercourse;hers;her;she;self-injury;th...         0.685987
# 1439                     dyadic relationship;pussy;fuck         0.606583
# 1459  partner;hand;image;she;Niger;myalgic encephalo...         0.570296
# 1461  instant messaging;bitch;Saudi Arabia;im;yo;fuc...         0.537492
# 1485         immigrant;hers;her;money;she;justice;her'n         0.544875
# 1498                              family;hers;her;her'n         0.579551
# 1520  mixed-orientation marriage;hers;her;she;her'n;...         0.689378
# 1575  sibling;married;literacy;hers;her;she;country;...         0.657187
# 1632  flatulence;labor;hers;her;party;intimidative s...         0.534922
# 1634   das;pussy;right;bitch;YAASSS;fuck;white identity         0.647118
# 1650              bisexual;bisexual person;love;Germany         0.775184
# 1661  sucking;hers;her;other identity;she;religion;h...         0.686797
# 1699  artist;set;family;hers;her;she;jail;California...         0.584999
# 1713                   death;hers;her;she;Somalia;her'n         0.614498
# 1777        movement;bitch;myalgic encephalomyelitis;me         0.519281

# %%
# we take max from each type: e.g. (compare category with table above)
d.loc[d.categories==5, ['categories'] + [f'target_gso_{p}' for p in ['Label', 'Pred']]]
# Out:
#       categories                                   target_gso_Label  \
# 568            5  movement;bitch;myalgic encephalomyelitis;me;fu...
# 1777           5        movement;bitch;myalgic encephalomyelitis;me
#
#       target_gso_Pred
# 568          0.503954
# 1777         0.519281

# %%
# entities which we have sampled and their id
example_entities = {}
for example_id in d_sampling.loc[d_sampling.index.isin(max_indices), id_col].tolist():
    example_entities[example_id] = d.loc[d[id_col]==example_id,'target_gso_Label'].to_list()[0].split(';')[0]
print(example_entities)
# Out:
# {888: 'hole', 6425: 'LGBT', 12497: 'woman', 13570: 'homophobia', 15066: 'man', 18174: 'gay', 18453: 'homosexualism', 18643: 'parent', 20522: 'mouth', 20952: 'friend', 21431: 'semen', 22115: 'life', 22145: 'marital partner', 22764: 'gender', 23572: '.gay', 23961: 'sexuality', 24928: 'anal intercourse', 24968: 'interpersonal attraction', 25616: 'body', 26413: 'heterosexual', 26720: 'face', 27022: 'pussy', 27941: 'rapist', 28485: 'sex', 30388: 'LGBTQ', 31220: 'male gender identity', 32077: 'muxe', 32925: 'clothing', 33276: 'marriage', 34548: 't!un', 39114: 'pornography', 39594: 'HIV positive', 39900: 'word', 40398: 'personal name', 40906: 'bitch', 41735: 'community', 41737: 'single person', 42143: 'hers', 42315: 'faggot', 42363: 'female gender identity', 42814: 'sexual intercourse', 43080: 'dyadic relationship', 43420: 'partner', 43491: 'instant messaging', 43987: 'immigrant', 44278: 'family', 44627: 'mixed-orientation marriage', 45777: 'sibling', 47124: 'flatulence', 47143: 'das', 47428: 'bisexual', 47572: 'sucking', 48228: 'artist', 48450: 'death', 49708: 'movement'}

# %%
# Export json: path to get their texts and predictions, ids for sample
sampling = {}
sampling['mhs'] = {'path': os.path.join('data_selection', 'mhs_fp.csv'), 'ids': ids}

# %% [markdown]
# ### Same in OOD

# %%
# Same with xtremespeech, gabhate and hatexplain
def draw_diverse_sample(df, 
                        col_categories = 'target_gso_Def', 
                        col_prob = 'target_gso_Pred', 
                        col_id=id_col):
    sample_ids = []
    # Encode by high relevant entities
    df['entity_id'] = df[col_categories].astype('category').cat.codes
    
    # Include ids from unique occurrences
    y = df['entity_id']
    y_counts = y.value_counts().to_dict()
    print('ocurring more than twice:', len([k for k,v in y_counts.items() if v > 2]))
    print('once or twice:', len([k for k,v in y_counts.items() if v <= 2]))

    # Include ids from unique occurrences
    unique = [k for k,v in y_counts.items() if v<2]
    sample_ids+=df[y.isin(unique)][col_id].to_list()

    # Include ids from repeated entities with highest probability
    df_repeated = df[~(y.isin(unique))]
    max_indices = df_repeated.groupby('entity_id')[col_prob].idxmax()
    sample_ids+=df_repeated.loc[df_repeated.index.isin(max_indices), col_id].tolist()
    
    print(f'({len(unique)}) unique + ({len(max_indices)}) repeated = ({len(y_counts)}) entities')
    print(len(sample_ids))
    return sample_ids

# %%
text_col, id_col = 'predict_text', 'comment_id'
dnames = ['mhs', 'gabhatecorpus', 'hatexplain', 'xtremespeech']

sampling = {}

for dname in dnames:
    print(dname.upper())
    path_i = os.path.join('data_selection', f'{dname}_fp.csv')
    d_i = pd.read_csv(path_i)
    print(d_i.shape)
    print(d_i.columns)

    ids_i = draw_diverse_sample(d_i)
    sampling[dname] = {'path': path_i, 'ids': ids_i}
# Out:
# MHS
# (1789, 63)
# Index(['comment_id', 'target_age', 'target_age_children',
#        'target_age_middle_aged', 'target_age_other', 'target_age_seniors',
#        'target_age_teenagers', 'target_age_young_adults', 'target_disability',
#        'target_disability_cognitive', 'target_disability_hearing_impaired',
#        'target_disability_neurological', 'target_disability_other',
#        'target_disability_physical', 'target_disability_unspecific',
#        'target_disability_visually_impaired', 'target_gender',
#        'target_gender_men', 'target_gender_non_binary', 'target_gender_other',
#        'target_gender_othergender', 'target_gender_transgender',
#        'target_gender_transgender_men',
#        'target_gender_transgender_unspecified',
#        'target_gender_transgender_women', 'target_gender_women', 'target_gso',
#        'target_gso_Pred', 'target_gso_IRI', 'target_gso_Label',
#        'target_gso_Def', 'target_origin', 'target_origin_immigrant',
#        'target_origin_migrant_worker', 'target_origin_other',
#        'target_origin_specific_country', 'target_origin_undocumented',
#        'target_race', 'target_race_asian', 'target_race_black',
#        'target_race_latinx', 'target_race_middle_eastern',
#        'target_race_native_american', 'target_race_other',
#        'target_race_pacific_islander', 'target_race_white', 'target_religion',
#        'target_religion_atheist', 'target_religion_buddhist',
#        'target_religion_christian', 'target_religion_hindu',
#        'target_religion_jewish', 'target_religion_mormon',
#        'target_religion_muslim', 'target_religion_other', 'target_sexuality',
#        'target_sexuality_bisexual', 'target_sexuality_gay',
#        'target_sexuality_homosexual', 'target_sexuality_lesbian',
#        'target_sexuality_other', 'target_sexuality_straight', 'predict_text'],
#       dtype='object')
# ocurring more than twice: 36
# once or twice: 94
# (75) unique + (55) repeated = (130) entities
# 130
# GABHATECORPUS
# (478, 28)
# Index(['comment_id', 'GEN', 'SXO', 'REL', 'RAE', 'MPH', 'NAT', 'IDL_POL',
#        'predict_text', 'target_gender', 'gender_list', 'target_sexuality',
#        'sexual_orientation_list', 'target_religion', 'religion_list',
#        'target_race', 'race_list', 'target_disability', 'disability_list',
#        'target_origin', 'origin_list', 'politics', 'politics_list',
#        'target_gso', 'target_gso_Pred', 'target_gso_IRI', 'target_gso_Label',
#        'target_gso_Def'],
#       dtype='object')
# ocurring more than twice: 20
# once or twice: 64
# (48) unique + (36) repeated = (84) entities
# 84
# HATEXPLAIN
# (1303, 36)
# Index(['comment_id', 'text', 'predict_text', 'annotatorid1', 'target1',
#        'label1', 'annotatorid2', 'target2', 'label2', 'annotatorid3',
#        'target3', 'label3', 'rationales', 'final_label', 'final_target',
#        'gender_list', 'target_gender', 'sexual_orientation_list',
#        'target_sexuality', 'religion_list', 'target_religion', 'race_list',
#        'target_race', 'origin_list', 'target_origin', 'disability_list',
#        'target_disability', 'economic_status_list', 'economic_status',
#        'miscellaneous_list', 'miscellaneous', 'target_gso', 'target_gso_Pred',
#        'target_gso_IRI', 'target_gso_Label', 'target_gso_Def'],
#       dtype='object')
# ocurring more than twice: 37
# once or twice: 81
# (69) unique + (49) repeated = (118) entities
# 118
# XTREMESPEECH
# (182, 34)
# Index(['predict_text', 'comment_id', 'Country', 'Language', 'Label',
#        'Target (protected)', 'Target (others)', 'Directed at fact-checkers',
#        'User', 'Comments', 'Status', 'Date', 'text', 'label', 'fact', 'split',
#        'country', 'gender_list', 'target_gender', 'sexual_orientation_list',
#        'target_sexuality', 'religion_list', 'target_religion', 'race_list',
#        'target_race', 'economic_status_list', 'economic_status', 'other_list',
#        'other', 'target_gso', 'target_gso_Pred', 'target_gso_IRI',
#        'target_gso_Label', 'target_gso_Def'],
#       dtype='object')
# ocurring more than twice: 5
# once or twice: 13
# (8) unique + (10) repeated = (18) entities
# 18

# %%
# Counts from each dataset
130+84+118+18
# Out:
# 350

# %%
# export sampled ids
with open(os.path.join(out_path, 'sampling.json'), 'w') as file:
    json.dump(sampling, file)
